# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## 1 - Basic plot

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("ggplot")

# %%
x = [1,2,3,4]
y = [10, 6, 8, 20]

# %%
plt.plot(x, y, color="green");

# %%
x = np.linspace(2,8,100)
y = np.sin(x)
y
# Out:
# array([ 0.90929743,  0.88242239,  0.85230712,  0.8190622 ,  0.78280971,
#         0.74368277,  0.70182505,  0.65739025,  0.61054153,  0.56145091,
#         0.51029867,  0.45727263,  0.40256749,  0.34638414,  0.28892887,
#         0.23041267,  0.1710504 ,  0.11106004,  0.05066187, -0.00992234,
#        -0.0704701 , -0.1307591 , -0.19056796, -0.24967706, -0.30786935,
#        -0.36493116, -0.42065295, -0.47483011, -0.52726371, -0.57776122,
#        -0.6261372 , -0.67221402, -0.7158225 , -0.7568025 , -0.79500354,
#        -0.83028535, -0.86251837, -0.89158426, -0.91737627, -0.93979971,
#        -0.95877223, -0.97422416, -0.98609877, -0.99435246, -0.99895492,
#        -0.99988924, -0.997152  , -0.99075324, -0.98071647, -0.96707854,
#        -0.94988952, -0.92921254, -0.90512352, -0.87771091, -0.84707537,
#        -0.81332939, -0.7765969 , -0.73701276, -0.69472233, -0.64988091,
#        -0.60265314, -0.55321244, -0.50174037, -0.44842592, -0.39346486,
# ...

# %%
plt.plot(x, y);

# %%
x = np.linspace(0, 8, 100)
x
# Out:
# array([0.        , 0.08080808, 0.16161616, 0.24242424, 0.32323232,
#        0.4040404 , 0.48484848, 0.56565657, 0.64646465, 0.72727273,
#        0.80808081, 0.88888889, 0.96969697, 1.05050505, 1.13131313,
#        1.21212121, 1.29292929, 1.37373737, 1.45454545, 1.53535354,
#        1.61616162, 1.6969697 , 1.77777778, 1.85858586, 1.93939394,
#        2.02020202, 2.1010101 , 2.18181818, 2.26262626, 2.34343434,
#        2.42424242, 2.50505051, 2.58585859, 2.66666667, 2.74747475,
#        2.82828283, 2.90909091, 2.98989899, 3.07070707, 3.15151515,
#        3.23232323, 3.31313131, 3.39393939, 3.47474747, 3.55555556,
#        3.63636364, 3.71717172, 3.7979798 , 3.87878788, 3.95959596,
#        4.04040404, 4.12121212, 4.2020202 , 4.28282828, 4.36363636,
#        4.44444444, 4.52525253, 4.60606061, 4.68686869, 4.76767677,
#        4.84848485, 4.92929293, 5.01010101, 5.09090909, 5.17171717,
#        5.25252525, 5.33333333, 5.41414141, 5.49494949, 5.57575758,
# ...

# %%
plt.plot(x, np.sin(x), color="green", linestyle="dashed", label="Sin x");
plt.plot(x, np.cos(x), color="red", label="Cos x");
plt.xlabel("x")
plt.ylabel("y")

plt.legend();

# %%
x = np.linspace(0, 20, 100)
y = np.sin(x) + x

plt.plot(x, y)

# %%
x = np.linspace(0, 20, 100)
y = np.sin(x) + x

fig, ax = plt.subplots(figsize=(5,4))


fig.suptitle(" Figure ", fontsize=20)
ax.plot(x, y, c='g', linestyle='dashed')
ax.plot(x, y - np.cos(x), c='r')
ax.set_xlabel("Year")
ax.set_ylabel("Population")
ax.legend(["Sin", "Cos"])

plt.show()

# %%
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
# theta = np.arange(0, np.pi / 2, 0.01)
# plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %%
CONST_RAND = 1000

np.random.seed(CONST_RAND)

Size = 50
r = np.random.rand(Size)
theta = np.random.rand(Size)

plt.scatter(r, theta)

# %%
x = np.linspace(0, 20, 100)
y = np.sin(x) + x

fig, ax = plt.subplots(figsize=(5,4))


fig.suptitle(" Figure ", fontsize=20)
ax.plot(x, y, c='g', linestyle='dashed')
ax.plot(x, y - np.cos(x), c='r')
ax.set_xlabel("Year")
ax.set_ylabel("Population")
ax.legend(["Sin", "Cos"])

plt.show()

# %%
color = 'g'
linestyle = 'dashed'
linewidth = 5

fig, ax = plt.subplots(figsize=(10,10))
fig.suptitle('Our First plot', fontsize=30)
ax.plot(x, y, c=color, linestyle=linestyle, linewidth=linewidth)
ax.set_ylabel('function', fontsize = 30)
ax.set_xlabel('argument', fontsize = 30)
for xtick in ax.xaxis.get_major_ticks():
    xtick.label1.set_fontsize(10)
    
for ytick in ax.yaxis.get_major_ticks():
    ytick.label1.set_fontsize(10)
plt.show()

# %%
# plt.close(fig)

# %%
import math

fig, axes = plt.subplots(1,3, figsize=(12,3))
x = np.linspace(-5, 5, 100)

ax1, ax2, ax3 = axes
color = ['r', 'g', 'b']
linewidth = 5

ax1.plot(x, np.sin(x), c=color[0], linewidth=linewidth)
ax1.set_title("Sin")
ax1.set_xlabel("Variable")
ax1.set_ylabel("Sin x")


ax2.plot(x, np.cos(x), c=color[1], linewidth=linewidth)
ax2.set_title("Cos")
ax2.set_xlabel("Variable")
ax2.set_ylabel("Cos x")

ax3.plot(x, np.tan(x), c=color[2], linewidth=linewidth)
ax3.set_title("Tan")
ax3.set_xlabel("Variable")
ax3.set_ylabel("Tan x")
# Out:
# Text(0, 0.5, 'Tan x')

# %%
x = np.linspace(-5, 5, 100)

fig, axes = plt.subplots(1,3, figsize=(12,4))
ax1, ax2, ax3 = axes

# Config plot
color = ['r', 'g', 'b']
linewidth = 2

ax1.plot(x, np.sin(x), c=color[0], linewidth=linewidth)
ax1.set_title('Sin function')
ax1.set_xlabel('Var x')
ax1.set_ylabel('Sin x')

ax2.plot(x, np.cos(x), c=color[1], linewidth=linewidth)
ax2.set_title('Cos function')
ax2.set_xlabel('Var x')
ax2.set_ylabel('Cos x')

ax3.plot(x, np.tan(x), c=color[2], linewidth=linewidth)
ax3.set_title('Tan function')
ax3.set_xlabel('Var x')
ax3.set_ylabel('Tan x')

fig.suptitle("Math function")

plt.plot();

# %% [markdown]
# ## Pie Chart

# %%
import matplotlib.pyplot as plt

label = ["Tall", "Short", "Medium"]
data = [0.2, 0.4, 0.4]

plt.pie(data, labels=label);

# %%
labels = ['Python','C','C++','PHP','Java','Ruby']
data = [0.3, 0.2, 0.15, 0.05, 0.15, 0.05]

plt.figure(figsize=(8, 6))
plt.pie(data, labels=labels, startangle=90);
plt.legend(labels)

# %%
explode = [0.0, 0.08,0.0, 0.0, 0.1, 0]
plt.pie(data, labels=labels, explode=explode, startangle=90);
plt.suptitle("Popular Language Programing")
plt.legend(labels)

# %%
colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']

plt.pie(data,
        labels=labels,
        colors=colors,
        explode=explode,
        autopct='%.2f%%',
        shadow=True);

# %%
plt.pie(data,
        labels=labels,
        colors=colors,
        startangle=90,
        autopct='%.2f%%',
        wedgeprops={'width' : 0.2});

# %%
fig, ax = plt.subplots(figsize=(5, 5))
width = 0.2

fig.suptitle("Popular Framework")
framework_data = [45, 41, 10, 4]
framework_labels = ['.Net', 'Spring', 'Express', 'Django']
framework_colors = ['orange', 'teal', 'powderblue', 'green']


ax.pie(framework_data, labels=framework_labels, radius=1 - width, colors=framework_colors, wedgeprops={'width': width}, labeldistance=0.35);
ax.pie(data, labels=labels, radius=1, colors=colors, wedgeprops={'width': width});

# %%
import pandas as pd

# %%
df = pd.read_csv("archive/Iris.csv")
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df = df[["SepalLengthCm", "SepalWidthCm","PetalLengthCm", "PetalWidthCm"]]
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
plt.imshow(df.corr(), cmap='Spectral');
plt.colorbar();
plt.gcf().set_size_inches(5,5)

# %% [markdown]
# ## Bar char

# %%
plt.bar(labels, data);

# %%
plt.bar(labels, data)
plt.xlabel("Programmming Language")
plt.ylabel("Percent")
plt.yticks([0.0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3], [0, 5, 10, 15, 20, 25, 30])
plt.show();

# %%
plt.grid(color='green', linestyle='-', linewidth=0.5, axis='y')
plt.bar(labels, data)
plt.xlabel("Programming Language")
plt.ylabel("Percent")
plt.yticks([0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3], [0, 5, 10, 15, 20, 25, 30])
plt.show();

# %%
plt.bar([1,3,5,7,9], [2,7,2,1,5], label="First Bar")
plt.bar([2,4,6,8,10], [1,5,3,2,6], label="Second Bar", color='g')

plt.legend()

# %%
import matplotlib.pyplot as plt

# %%
def anotation_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i + 1), va = "center", ha = "center")
        ax.tick_params(labelleft = False, labelbottom = False)

# %%
fig = plt.figure();
fig.suptitle("Layout Axes")

from matplotlib.gridspec import GridSpec

gs0 = GridSpec(3 ,3, left = 0.05, right = 0.48, wspace = 0.05)
ax1 = fig.add_subplot(gs0[:-1, :])
ax2 = fig.add_subplot(gs0[-1, :-1])
ax3 = fig.add_subplot(gs0[-1, -1])

gs1 = GridSpec(3 ,3, left = 0.55, right = 0.98, hspace = 0.05)
ax4 = fig.add_subplot(gs1[:, :-1])
ax5 = fig.add_subplot(gs1[:-2, -1])
ax6 = fig.add_subplot(gs1[1:, -1])

anotation_axes(fig)
