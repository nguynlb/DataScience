# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from matplotlib import pyplot as plt

# %%
n_samples = 50
n_features = 3
X = np.ones((n_samples, n_features))
a = 2
b = -3
x1 = np.linspace(.0, 5, n_samples)
x2 = a * x + b + np.random.randn(n_samples)

X[:, 0], X[:, 1] = x1, x2
X[:, 2] = np.random.randn(n_samples) * 128

# %%
plt.scatter(X[:, 0], X[:, 1], cmap = plt.cm.coolwarm, c = X[:, 2])

pl
