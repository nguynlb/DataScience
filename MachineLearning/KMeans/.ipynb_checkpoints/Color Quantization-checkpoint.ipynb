# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
from sklearn.cluster import KMeans

# %%
image = imread("image.jpg")

w, h, d = image.shape

# %%
dataset = image.reshape((w * h, d))

# %%
n_colors = 2
n_init = 10
random_state = 123


common_params = {
    "n_init": n_init,
    "random_state": random_state
    
}

km = KMeans(n_clusters = n_colors, **common_params).fit(dataset)

# %%
labels = km.predict(dataset)
km.cluster_centers_
# Out:
# array([[100.44095723,  81.87470063,  57.58968711],
#        [189.44799565, 174.8064613 , 151.22113042]])

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
res_image = km.cluster_centers_[labels]

# %%
res_image = res_image.reshape(w, h, -1)

# %%
res_image = res_image.astype(int)

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 8))

ax1.imshow(image)
ax2.imshow(res_image)

# %%
np.sum((image - res_image) ** 2, axis = 1)
# Out:
# array([[1058748, 1874843, 1304903],
#        [1047767, 1874027, 1304521],
#        [1048933, 1892469, 1312822],
#        ...,
#        [ 833681,  710671,  579561],
#        [ 843571,  719952,  587400],
#        [ 852614,  727512,  593622]], dtype=int32)
